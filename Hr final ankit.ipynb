# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Users\Preeti kumari\Desktop\WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
corr_cols = df
df.corr(method ='pearson')
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %%
corr = corr_cols.corr()
plt.figure(figsize=(25,10))
sns.heatmap(corr,annot=True)
plt.show()

# %% [markdown]
# Obervation on the basis of this coloum we can see that the many coloums have a different correlation so we are droping the mulitple coloums
# as employee count and standardhours have NAN value they are no more important to us.

# %%
new_df=pd.DataFrame(data=df,columns=["Department","Attrition","EnvironmentSatisfaction","JobSatisfaction","JobInvolvement","YearsAtCompany","StockOptionLevel","YearsWithCurrManager","Age","MonthlyIncome","YearsInCurrentRole","JobLevel","TotalWorkingYears"])

# %%
def encode(Attrition):
    if Attrition=="No":
        label=1
    else:
        label=2
    return label

new_df["Attrition"]=new_df["Attrition"].apply(encode)
new_df["Attrition"]
# Out:
# 0       2
# 1       1
# 2       2
# 3       1
# 4       1
#        ..
# 1465    1
# 1466    1
# 1467    1
# 1468    1
# 1469    1
# Name: Attrition, Length: 1470, dtype: int64

# %%
new_df['Attrition'].value_counts()
# Out:
# 1    1233
# 2     237
# Name: Attrition, dtype: int64

# %%
pd.crosstab(new_df.Attrition,new_df.JobSatisfaction).plot(kind='bar')
# as we can see that the 1 being the lowest statisfaction and 4 is heighest satifacion, people with the less satisfaction has left the company.

# %%
df["JobInvolvement"].value_counts()
# Out:
# 3    868
# 2    375
# 4    144
# 1     83
# Name: JobInvolvement, dtype: int64

# %%
#numbers of employess left in diffrent department
pd.crosstab(new_df.Department,new_df.Attrition).plot(kind='bar')

# %%
sns.barplot(x="Attrition",y="MonthlyIncome",data=new_df)
#as we can see that the heigher the income the more the people stays in the company.

# %%
pd.crosstab(new_df.Attrition,new_df.JobInvolvement).plot(kind='bar')
#as we can see that the 1 being the lowest JobInvolvement and 4 is heighest JobInvolvement, people with the less JobInvolvement has left the company.

# %%
pd.crosstab(new_df.Attrition,new_df.EnvironmentSatisfaction).plot(kind='bar')

# %%
sns.barplot(x="Attrition",y="Age",data=new_df)

# %%
pd.crosstab(new_df.Attrition,new_df.StockOptionLevel).plot(kind='bar')

# %%
sns.barplot(x="Department",y="MonthlyIncome",data=new_df)
#diffrent income range of diffrent department

# %%
sns.barplot(x="Attrition",y="YearsAtCompany",hue="Department",data=new_df)
#as per this we can see that the people working in the hr department are working for the longer period of time as compare to the other department.

# %% [markdown]
# Visualising the outliers

# %%
def box_plot(x):
    f1, p1 = plt.subplots()
    p1.set_title(x)
    p1.boxplot(new_df[x])

# %%
box_plot('Age')

# %%
box_plot('MonthlyIncome')

# %%
box_plot('TotalWorkingYears')

# %%
box_plot('YearsAtCompany')

# %%
#encodingdepartment into numeric
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
new_df["Department"] = labelencoder.fit_transform(new_df["Department"])

# %%
new_df["Department"].value_counts()
# Out:
# 1    961
# 2    446
# 0     63
# Name: Department, dtype: int64

# %%
#checking skewness
new_df.skew()
# Out:
# Department                 0.172231
# Attrition                  1.844366
# EnvironmentSatisfaction   -0.321654
# JobSatisfaction           -0.329672
# JobInvolvement            -0.498419
# YearsAtCompany             1.764529
# StockOptionLevel           0.968980
# YearsWithCurrManager       0.833451
# Age                        0.413286
# MonthlyIncome              1.369817
# YearsInCurrentRole         0.917363
# JobLevel                   1.025401
# TotalWorkingYears          1.117172
# dtype: float64

# %%
#removing outliers
from scipy import stats
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(new_df))
threshold=3
print(np.where(z>3))
# Out:
# (array([  28,   62,   63,   85,   98,   98,  123,  123,  126,  126,  153,
#         187,  187,  190,  190,  231,  231,  237,  270,  270,  281,  386,
#         401,  411,  425,  445,  466,  473,  477,  561,  561,  592,  595,
#         595,  616,  624,  635,  653,  677,  686,  716,  746,  749,  861,
#         875,  894,  914,  918,  926,  956,  962,  976, 1024, 1043, 1078,
#        1086, 1111, 1116, 1116, 1135, 1138, 1184, 1301, 1327, 1348, 1351,
#        1401, 1430], dtype=int64), array([ 7,  5, 10, 12,  5, 12,  7, 10,  5, 12,  7,  7, 12,  5, 10,  7, 10,
#         5,  5, 12, 10,  7, 12,  5,  5, 12, 10,  5,  5,  5,  7,  5,  5, 12,
#         7, 12,  7,  5,  5,  7, 10, 10,  5,  5,  7, 12,  5,  5,  7, 12,  5,
#        10, 10, 12,  7,  5,  5,  5, 12,  5,  5, 12, 12, 10,  7, 10, 12, 10],
#       dtype=int64))

# %%
new_df =new_df[(z < 3).all(axis=1)]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1412 entries, 0 to 1469
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Department               1412 non-null   int32
#  1   Attrition                1412 non-null   int64
#  2   EnvironmentSatisfaction  1412 non-null   int64
#  3   JobSatisfaction          1412 non-null   int64
#  4   JobInvolvement           1412 non-null   int64
#  5   YearsAtCompany           1412 non-null   int64
#  6   StockOptionLevel         1412 non-null   int64
#  7   YearsWithCurrManager     1412 non-null   int64
#  8   Age                      1412 non-null   int64
#  9   MonthlyIncome            1412 non-null   int64
#  10  YearsInCurrentRole       1412 non-null   int64
#  11  JobLevel                 1412 non-null   int64
#  12  TotalWorkingYears        1412 non-null   int64
# dtypes: int32(1), int64(12)
# memory usage: 148.9 KB

# %%
X = new_df.drop('Attrition', axis = 1)
y = new_df['Attrition']

# %%
from sklearn.preprocessing import power_transform
df_skewed=power_transform(X,method="yeo-johnson")
X=pd.DataFrame(df_skewed,columns=X.columns)
# Out:
# C:\Users\Preeti kumari\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py:2995: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(X)
x=sc.transform(X)
x=pd.DataFrame(x,columns=X.columns)

# %%
X.shape
# Out:
# (1412, 12)

# %%
from sklearn.model_selection import train_test_split,cross_val_score
X_train, X_test, y_train, y_test = train_test_split(x ,y, test_size = 0.2, random_state = 42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.metrics import f1_score
from sklearn import svm  
from sklearn.metrics import precision_score
from sklearn.model_selection import cross_val_score

from sklearn.metrics import recall_score
from sklearn.model_selection import train_test_split

# %%
model=[LogisticRegression(),DecisionTreeClassifier(),svm.SVC(),RandomForestClassifier(),KNeighborsClassifier()]
for m in model:
    m.fit(X_train,y_train)
    pred=m.predict(X_test)
    print("Score of",m,"is",accuracy_score(y_test,pred))
    print("Cross val score:",cross_val_score(m,x,y,cv=3,scoring="accuracy").mean())
    print("\n")
# Out:
# Score of LogisticRegression() is 0.8798586572438163
# Cross val score: 0.8498622216199124
#
#
# Score of DecisionTreeClassifier() is 0.7561837455830389
# Cross val score: 0.7592251283672885
#
#
# Score of SVC() is 0.8763250883392226
# Cross val score: 0.8463221454277153
#
#
# Score of RandomForestClassifier() is 0.8798586572438163
# Cross val score: 0.8399482013521856
#
#
# Score of KNeighborsClassifier() is 0.8657243816254417
# Cross val score: 0.8300281579858758

# %%
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import GridSearchCV
model = LogisticRegression()
solvers = ['newton-cg', 'lbfgs', 'liblinear']
c_values = [100, 10, 1.0, 0.1, 0.01]
# define grid search
grid = dict(solver=solvers,C=c_values)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_search.fit(x,y)
print("Best Hyper Parameters:\n",grid_search.best_params_)

# summarize results
# Out:
# Best Hyper Parameters:
#  {'C': 0.1, 'solver': 'newton-cg'}

# %%
model1=LogisticRegression(random_state=45,C= 0.1, solver='newton-cg')
model1.fit(X_train,y_train)
pred=model1.predict(X_test)
print("Accuracy for Logistic Regression on CV data: ",accuracy_score(y_test,pred))
# Out:
# Accuracy for Logistic Regression on CV data:  0.8904593639575972

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import f1_score
print("Confusion matrix \n",confusion_matrix(y_test,pred))
print("classification report \n",classification_report(y_test,pred))
# Out:
# Confusion matrix
#  [[245   3]
#  [ 28   7]]
# classification report
#                precision    recall  f1-score   support
#
#            1       0.90      0.99      0.94       248
#            2       0.70      0.20      0.31        35
#
#     accuracy                           0.89       283
#    macro avg       0.80      0.59      0.63       283
# weighted avg       0.87      0.89      0.86       283

# %%
df_result=pd.DataFrame(pred)

# %%
df_result.to_csv('Output.csv')

# %%
import joblib
joblib.dump(grid_search,"Hr.attrion")
