# %%
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
df=pd.read_csv("avocado dataset.csv")

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0             0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1             1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2             2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3             3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4             4.0  29-11-2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 16463         NaN         NaN           NaN           NaN      NaN        NaN
# 16464         NaN         NaN           NaN           NaN      NaN        NaN
# 16465         NaN         NaN           NaN           NaN      NaN        NaN
# 16466         NaN         NaN           NaN           NaN      NaN        NaN
# 16467         NaN         NaN           NaN           NaN      NaN        NaN
#
# ...

# %%
df=df.dropna(how='all')
#dropping all columns with null values

# %%
df.info()
#all values are present
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1517 entries, 0 to 1516
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1517 non-null   float64
#  1   Date          1517 non-null   object
#  2   AveragePrice  1517 non-null   float64
#  3   Total Volume  1517 non-null   float64
#  4   4046          1517 non-null   float64
#  5   4225          1517 non-null   float64
#  6   4770          1517 non-null   float64
#  7   Total Bags    1517 non-null   float64
#  8   Small Bags    1517 non-null   float64
#  9   Large Bags    1517 non-null   float64
#  10  XLarge Bags   1517 non-null   float64
#  11  type          1517 non-null   object
#  12  year          1517 non-null   float64
#  13  region        1517 non-null   object
# dtypes: float64(11), object(3)
# memory usage: 177.8+ KB

# %%
df.describe()
# Out:
#         Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  1517.000000   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03
# mean     26.995386      1.074990  1.601879e+06  6.464387e+05  6.114375e+05
# std      14.848287      0.188891  4.433143e+06  1.947614e+06  1.672906e+06
# min       0.000000      0.490000  3.875074e+04  4.677200e+02  1.783770e+03
# 25%      14.000000      0.980000  1.474700e+05  2.040034e+04  4.147606e+04
# 50%      29.000000      1.080000  4.027919e+05  8.175117e+04  1.186649e+05
# 75%      39.000000      1.190000  9.819751e+05  3.775785e+05  4.851503e+05
# max      51.000000      1.680000  4.465546e+07  1.893304e+07  1.895648e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000
# mean   5.040550e+04  2.935974e+05  2.487736e+05  4.264205e+04    2181.771074
# ...

# %%
plt.figure(figsize=(50,20))
plt.xlabel("Region", fontsize=40)
plt.ylabel("AveragePrice", fontsize=40)
plt.xticks(rotation=90,fontsize=30)
plt.yticks(rotation=0,fontsize=25)
sns.barplot(x="region",y="AveragePrice",data=df)
#plotting the graph by taking x axis as region,y axis as average price and hue as year

# %% [markdown]
# Observation:
#
#  Syracuse has highest average price among all

# %%
plt.figure(figsize=(50,20))
plt.xlabel("Region", fontsize=40)
plt.ylabel("Total Bags", fontsize=40)
plt.xticks(rotation=90,fontsize=30)
plt.yticks(rotation=0,fontsize=25)
sns.barplot(x="region",y="Total Bags",data=df)

# %% [markdown]
# From the above we can see the heighest number of bags are in Total USA

# %% [markdown]
# Encoding the  column region

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
df["region"] = labelencoder.fit_transform(df["region"])
# Out:
# <ipython-input-143-0702a4338564>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["region"] = labelencoder.fit_transform(df["region"])

# %%
corr_matrix=df.corr()
corr_matrix["region"].sort_values(ascending=False)
#dropping columns with less correlation
# Out:
# region          1.000000
# Large Bags      0.297452
# 4046            0.269481
# Total Volume    0.236579
# 4225            0.215733
# Total Bags      0.190001
# Small Bags      0.168650
# 4770            0.138092
# Unnamed: 0      0.012123
# XLarge Bags    -0.046144
# AveragePrice   -0.229408
# year           -0.470472
# Name: region, dtype: float64

# %%
df.type.value_counts()
#as all are conventional so we can drop this column
# Out:
# conventional    1517
# Name: type, dtype: int64

# %%
#dropping columns 
df.drop(columns=["XLarge Bags","Total Bags","Total Volume","type","Unnamed: 0","Date"],axis=1,inplace=True)
#total bags isthe sum of small bags,large bags and x large bags so dropping that and also dropping totalvolume as it is just the sum of
# Out:
# C:\Users\Preeti kumari\anaconda3\lib\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), vmax=0.6, square=True, annot=True)
#positive correlation

# %%
df.skew()
#finding skewness
# Out:
# AveragePrice   -0.109444
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Small Bags      5.355185
# Large Bags      5.144495
# year            1.828332
# region          0.288146
# dtype: float64

# %%
df.head()
# Out:
#    AveragePrice     4046       4225    4770  Small Bags  Large Bags    year  \
# 0          1.33  1036.74   54454.85   48.16     8603.62       93.25  2015.0
# 1          1.35   674.28   44638.81   58.33     9408.07       97.49  2015.0
# 2          0.93   794.70  109149.67  130.50     8042.21      103.14  2015.0
# 3          1.08  1132.00   71976.41   72.58     5677.40      133.76  2015.0
# 4          1.28   941.48   43838.39   75.78     5986.26      197.69  2015.0
#
#    region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
import numpy as np
for col in df.columns:
    if df.skew().loc[col]>1.5:
        df[col]=np.log1p(df[col])
# Out:
# <ipython-input-150-65dd28fa3945>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col]=np.log1p(df[col])

# %%
df.head()
# Out:
#    AveragePrice      4046       4225      4770  Small Bags  Large Bags  \
# 0          1.33  6.944801  10.905146  3.895080    9.060055    4.545951
# 1          1.35  6.515127  10.706381  4.083115    9.149429    4.589955
# 2          0.93  6.679222  11.600485  4.879007    8.992584    4.645736
# 3          1.08  7.032624  11.184108  4.298373    8.644425    4.903495
# 4          1.28  6.848515  10.688288  4.340944    8.697389    5.291746
#
#        year  region
# 0  7.608871       0
# 1  7.608871       0
# 2  7.608871       0
# 3  7.608871       0
# 4  7.608871       0

# %%
df.skew()
# Out:
# AveragePrice    0.021101
# 4046           -0.012059
# 4225            0.008450
# 4770           -0.032945
# Small Bags      0.027632
# Large Bags     -0.074795
# year            0.000000
# region         -0.209568
# dtype: float64

# %%
from scipy import stats
from scipy import stats
import numpy as np
z = np.abs(stats.zscore(df))
threshold=3
df =df[(z < 3).all(axis=1)]
#removing outliers

# %%
x=df.drop("region",axis=1)
y=df["region"]
#splitting into input and output part

# %%
df.head()
# Out:
#    AveragePrice      4046       4225      4770  Small Bags  Large Bags  \
# 0          1.33  6.944801  10.905146  3.895080    9.060055    4.545951
# 1          1.35  6.515127  10.706381  4.083115    9.149429    4.589955
# 2          0.93  6.679222  11.600485  4.879007    8.992584    4.645736
# 3          1.08  7.032624  11.184108  4.298373    8.644425    4.903495
# 4          1.28  6.848515  10.688288  4.340944    8.697389    5.291746
#
#        year  region
# 0  7.608871       0
# 1  7.608871       0
# 2  7.608871       0
# 3  7.608871       0
# 4  7.608871       0

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(x)
X=sc.transform(x)
X=pd.DataFrame(X,columns=x.columns)
#scaling the columns of

# %%
from sklearn.ensemble import RandomForestClassifier

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.metrics import f1_score
from sklearn import svm  
from sklearn.metrics import precision_score
from sklearn.model_selection import cross_val_score

from sklearn.metrics import recall_score
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x, y,random_state = 45,test_size=0.20)

# %%
model=[DecisionTreeClassifier(),svm.SVC(),RandomForestClassifier(),KNeighborsClassifier()]
for m in model:
    m.fit(x_train,y_train)
    predm=m.predict(x_test)
    print("Score of",m,"is",accuracy_score(y_test,predm))
    print("Cross val score:",cross_val_score(m,x,y,cv=3,scoring="accuracy").mean())
    print("\n")
# Out:
# Score of DecisionTreeClassifier() is 0.8637873754152824
# Cross val score: 0.6897201612710834
#
#
# Score of SVC() is 0.6112956810631229
# Cross val score: 0.5528292684219873
#
#
# Score of RandomForestClassifier() is 0.9700996677740864
# Cross val score: 0.859148900075016
#
#
# Score of KNeighborsClassifier() is 0.9169435215946844
# Cross val score: 0.8219271947472916

# %% [markdown]
# Observation
#   .Using KNeighborsClassifier to evalute the model now as it is not very high and not very low

# %%
from sklearn.model_selection import GridSearchCV
model=KNeighborsClassifier()
params = {'n_neighbors':[5,6,7,8,9,10],
          'leaf_size':[1,2,3,5],
          'weights':['uniform', 'distance'],
          'algorithm':['auto', 'ball_tree','kd_tree','brute'],
          'n_jobs':[-1]}
gs = GridSearchCV(model, param_grid=params, n_jobs=1)
gs.fit(x,y)
print("Best Hyper Parameters:\n",gs.best_params_)
#hyperparameter tuning for better score
# Out:
# C:\Users\Preeti kumari\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:670: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# Best Hyper Parameters:
#  {'algorithm': 'auto', 'leaf_size': 1, 'n_jobs': -1, 'n_neighbors': 6, 'weights': 'distance'}

# %%
#Now using the hyper parameters 
knn=KNeighborsClassifier(leaf_size= 1, n_jobs= -1, n_neighbors= 6, weights= 'distance')
knn.fit(x_train,y_train)
knn_y=knn.predict(x_test)
print("Accuracy score is:",accuracy_score(y_test,knn_y))
print("F1 score is:",f1_score(y_test,knn_y,average='macro'))
print('Precision score is:',precision_score(y_test, ypred, average='macro'))
print("Recall score is:",recall_score(y_test,ypred,average="macro"))
# Out:
# Accuracy score is: 0.9269102990033222
# F1 score is: 0.9061169582051934
# Precision score is: 0.9144675324675324
# Recall score is: 0.9344595959595959

# %%
df_new=pd.DataFrame(knn_y)

# %%
df_new.to_csv('Output.csv')

# %%
import joblib
joblib.dump(knn,"region_pr.pkl")
# Out:
# ['region_pr.pkl']
